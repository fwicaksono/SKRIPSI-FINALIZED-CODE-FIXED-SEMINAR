# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('Dataset.csv')
df_mepas = df[df['station'] == 'MEPAS']
df_mepas
# Out:
#             mean  standard_deviation  median  min_value  max_value  range  \
# 0     -61.153897         2418.248336   -45.0      -7993       8313  16306
# 1     -54.996003         2895.323315   -61.0     -12868      11103  23971
# 2     -42.185210         1380.788970   -79.0      -5319       7881  13200
# 5      74.065290         3123.231066   102.0     -11838      10949  22787
# 6     -17.023984         4120.699543   153.0     -18413      13956  32369
# ...          ...                 ...     ...        ...        ...    ...
# 1421    0.914724         8001.826712   -93.0     -37351      41437  78788
# 1422    0.055963         3014.456105   -25.0     -12833       9931  22764
# 1423  -41.770153         3989.381765   -55.0     -20033      17878  37911
# 1424  310.812791         3725.247662   395.0     -16810      14033  30843
# 1425 -118.743504        10286.564361     5.0     -33741      47380  81121
#
#       interquartile_range      q1      q3  kurtosis  skewness station channel  \
# 0                  3074.0 -1583.0  1491.0  0.502047  0.119469   MEPAS     HHE
# 1                  3584.0 -1908.0  1676.0  1.251162  0.056173   MEPAS     HHN
# 2                  1770.0  -940.0   830.0  2.039666  0.402137   MEPAS     HHZ
# 5                  2156.0 -1020.0  1136.0  2.117157 -0.108686   MEPAS     HHE
# 6                  2701.0 -1205.0  1496.0  2.810478 -0.367038   MEPAS     HHN
# ...                   ...     ...     ...       ...       ...     ...     ...
# 1421               4642.0 -2369.0  2273.0  4.644935  0.284193   MEPAS     HHE
# 1422               3304.0 -1643.0  1661.0  1.331211 -0.185915   MEPAS     HHE
# 1423               4470.0 -2382.0  2088.0  1.751039  0.021382   MEPAS     HHE
# 1424               3997.0 -1665.0  2332.0  1.618849 -0.228880   MEPAS     HHE
# 1425              13502.0 -6939.0  6563.0  0.447013  0.123296   MEPAS     HHE
#
#        class
# 0     BEBENG
# 1     BEBENG
# 2     BEBENG
# 5     BEBENG
# 6     BEBENG
# ...      ...
# 1421  GENDOL
# 1422  GENDOL
# 1423  GENDOL
# 1424  GENDOL
# 1425  GENDOL
#
# [772 rows x 14 columns]

# %% [markdown]
# ## Fillna with 0

# %%
df_mepas.isnull().sum()
# Out:
# mean                   0
# standard_deviation     0
# median                 0
# min_value              0
# max_value              0
# range                  0
# interquartile_range    0
# q1                     0
# q3                     0
# kurtosis               0
# skewness               0
# station                0
# channel                0
# class                  0
# dtype: int64

# %%
df_mepas.fillna(0, inplace=True)
# Out:
# <ipython-input-5-a5e51832fbcd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mepas.fillna(0, inplace=True)

# %%
df_mepas.isnull().sum()
# Out:
# mean                   0
# standard_deviation     0
# median                 0
# min_value              0
# max_value              0
# range                  0
# interquartile_range    0
# q1                     0
# q3                     0
# kurtosis               0
# skewness               0
# station                0
# channel                0
# class                  0
# dtype: int64

# %% [markdown]
# ## Persebaran Kelas

# %%
count_boyong = len(df_mepas[df_mepas['class'] == 'BOYONG'])
count_bebeng = len(df_mepas[df_mepas['class'] == 'BEBENG'])


print(count_boyong)
print(count_bebeng)
# Out:
# 55
# 683

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE

# Assuming merged_df is your DataFrame
# Separate features and labels
X = df_mepas.drop(['class','station', 'channel'], axis=1)
y = df_mepas['class']

# Label encoding for the target label
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.1, stratify=y_encoded, random_state=42)

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
print("========================SEBELUM SMOTE========================== \n")

# Mendapatkan jumlah data untuk setiap kelas dalam y_train dan y_test
train_class_counts = pd.Series(y_train).value_counts()
test_class_counts = pd.Series(y_test).value_counts()

# Menampilkan jumlah data untuk setiap kelas
print("Data Latih:")
for class_label, count in train_class_counts.items():
    print(f"{label_encoder.inverse_transform([class_label])[0]} = {count} data")

print("\nData Uji:")
for class_label, count in test_class_counts.items():
    print(f"{label_encoder.inverse_transform([class_label])[0]} = {count} data")
    
print("========================SESUDAH SMOTE========================== \n")
# Mendapatkan jumlah data untuk setiap kelas dalam y_train dan y_test
train_class_counts = pd.Series(y_train_smote).value_counts()
test_class_counts = pd.Series(y_test).value_counts()

print("Data Latih:")
for class_label, count in train_class_counts.items():
    print(f"{label_encoder.inverse_transform([class_label])[0]} = {count} data")

print("\nData Uji:")
for class_label, count in test_class_counts.items():
    print(f"{label_encoder.inverse_transform([class_label])[0]} = {count} data")
# Out:
# ========================SEBELUM SMOTE==========================
#
# Data Latih:
# BEBENG = 614 data
# BOYONG = 49 data
# GENDOL = 31 data
#
# Data Uji:
# BEBENG = 69 data
# BOYONG = 6 data
# GENDOL = 3 data
# ========================SESUDAH SMOTE==========================
#
# Data Latih:
# BEBENG = 614 data
# BOYONG = 614 data
# GENDOL = 614 data
#
# Data Uji:
# BEBENG = 69 data
# BOYONG = 6 data
# GENDOL = 3 data

# %%
class_names = df_mepas['class'].unique()

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Inisialisasi model KNN
knn_model = KNeighborsClassifier()

# Tentukan rentang nilai K yang ingin dieksplorasi
param_dist = {
    'n_neighbors': range(1, 15),
    'leaf_size': range(20, 60),
    'p' : [2]
}
  # Contoh: kita ingin mencoba nilai K dari 1 hingga 20

# Inisialisasi objek RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=knn_model, param_distributions=param_dist, n_iter=100, cv=3, scoring='accuracy', random_state=42)

# Latih model menggunakan Random Search
random_search.fit(X_train_smote, y_train_smote)

# Tampilkan hasil pencarian parameter
print("Best parameter (K):", random_search.best_params_)
print("Best cross-validation score:", random_search.best_score_)

# Evaluasi model terbaik pada data uji
best_knn_model = random_search.best_estimator_
y_pred = best_knn_model.predict(X_test)

# Tampilkan laporan klasifikasi
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Best parameter (K): {'p': 2, 'n_neighbors': 1, 'leaf_size': 30}
# Best cross-validation score: 0.8219326818675353
#               precision    recall  f1-score   support
#
#       BEBENG       0.90      0.75      0.82        69
#       BOYONG       0.07      0.17      0.10         6
#       GENDOL       0.20      0.33      0.25         3
#
#     accuracy                           0.69        78
#    macro avg       0.39      0.42      0.39        78
# weighted avg       0.81      0.69      0.74        78

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Inisialisasi model KNN
knn_model = KNeighborsClassifier()

# Tentukan rentang nilai K yang ingin dieksplorasi
param_dist = {
    'n_neighbors': range(1, 15),
    'leaf_size': range(20, 60),
    'p' : [2]
}
  # Contoh: kita ingin mencoba nilai K dari 1 hingga 20

# Inisialisasi objek RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=knn_model, param_distributions=param_dist, n_iter=100, cv=5, scoring='accuracy', random_state=42)

# Latih model menggunakan Random Search
random_search.fit(X_train_smote, y_train_smote)

# Tampilkan hasil pencarian parameter
print("Best parameter (K):", random_search.best_params_)
print("Best cross-validation score:", random_search.best_score_)

# Evaluasi model terbaik pada data uji
best_knn_model = random_search.best_estimator_
y_pred = best_knn_model.predict(X_test)

# Tampilkan laporan klasifikasi
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Best parameter (K): {'p': 2, 'n_neighbors': 1, 'leaf_size': 30}
# Best cross-validation score: 0.8431233062330623
#               precision    recall  f1-score   support
#
#       BEBENG       0.90      0.75      0.82        69
#       BOYONG       0.07      0.17      0.10         6
#       GENDOL       0.20      0.33      0.25         3
#
#     accuracy                           0.69        78
#    macro avg       0.39      0.42      0.39        78
# weighted avg       0.81      0.69      0.74        78

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Inisialisasi model KNN
knn_model = KNeighborsClassifier()

# Tentukan rentang nilai K yang ingin dieksplorasi
param_dist = {
    'n_neighbors': range(1, 15),
    'leaf_size': range(20, 60),
    'p' : [2]
}
  # Contoh: kita ingin mencoba nilai K dari 1 hingga 20

# Inisialisasi objek RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=knn_model, param_distributions=param_dist, n_iter=100, cv=10, scoring='accuracy', random_state=42)

# Latih model menggunakan Random Search
random_search.fit(X_train_smote, y_train_smote)

# Tampilkan hasil pencarian parameter
print("Best parameter (K):", random_search.best_params_)
print("Best cross-validation score:", random_search.best_score_)

# Evaluasi model terbaik pada data uji
best_knn_model = random_search.best_estimator_
y_pred = best_knn_model.predict(X_test)

# Tampilkan laporan klasifikasi
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Best parameter (K): {'p': 2, 'n_neighbors': 1, 'leaf_size': 30}
# Best cross-validation score: 0.8458578143360752
#               precision    recall  f1-score   support
#
#       BEBENG       0.90      0.75      0.82        69
#       BOYONG       0.07      0.17      0.10         6
#       GENDOL       0.20      0.33      0.25         3
#
#     accuracy                           0.69        78
#    macro avg       0.39      0.42      0.39        78
# weighted avg       0.81      0.69      0.74        78
